# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20200604132123-0000
# KERNEL_ID = fe9de073-068b-4210-b74a-fb1e4d4ea370
#    Unnamed: 0  interest_rate  credit  march  may  previous  duration    y
# 0           0          1.313     0.0    1.0  0.0       0.0     487.0   no
# 1           1          4.961     0.0    0.0  0.0       0.0     132.0   no
# 2           2          4.856     0.0    1.0  0.0       0.0      92.0   no
# 3           3          4.120     0.0    0.0  0.0       0.0    1468.0  yes
# 4           4          4.963     0.0    0.0  0.0       0.0      36.0   no

# %%
raw_data = df_data_1.copy()
raw_data.head(25)
# Out:
#     Unnamed: 0  interest_rate  credit  march  may  previous  duration    y
# 0            0          1.313     0.0    1.0  0.0       0.0     487.0   no
# 1            1          4.961     0.0    0.0  0.0       0.0     132.0   no
# 2            2          4.856     0.0    1.0  0.0       0.0      92.0   no
# 3            3          4.120     0.0    0.0  0.0       0.0    1468.0  yes
# 4            4          4.963     0.0    0.0  0.0       0.0      36.0   no
# 5            5          0.697     0.0    1.0  4.0       0.0     131.0   no
# 6            6          0.639     1.0    0.0  0.0       0.0     215.0  yes
# 7            7          4.120     0.0    0.0  0.0       0.0     499.0   no
# 8            8          1.281     0.0    1.0  1.0       0.0     809.0  yes
# 9            9          4.966     0.0    0.0  0.0       0.0     389.0   no
# 10          10          4.965     0.0    0.0  0.0       0.0     168.0   no
# ...

# %%
raw_data = raw_data.drop(['Unnamed: 0'], axis = 1)
raw_data.head(10)
# Out:
#    interest_rate  credit  march  may  previous  duration    y
# 0          1.313     0.0    1.0  0.0       0.0     487.0   no
# 1          4.961     0.0    0.0  0.0       0.0     132.0   no
# 2          4.856     0.0    1.0  0.0       0.0      92.0   no
# 3          4.120     0.0    0.0  0.0       0.0    1468.0  yes
# 4          4.963     0.0    0.0  0.0       0.0      36.0   no
# 5          0.697     0.0    1.0  4.0       0.0     131.0   no
# 6          0.639     1.0    0.0  0.0       0.0     215.0  yes
# 7          4.120     0.0    0.0  0.0       0.0     499.0   no
# 8          1.281     0.0    1.0  1.0       0.0     809.0  yes
# 9          4.966     0.0    0.0  0.0       0.0     389.0   no

# %%
data_clean = raw_data.copy()
data_clean.head()
# Out:
#    interest_rate  credit  march  may  previous  duration    y
# 0          1.313     0.0    1.0  0.0       0.0     487.0   no
# 1          4.961     0.0    0.0  0.0       0.0     132.0   no
# 2          4.856     0.0    1.0  0.0       0.0      92.0   no
# 3          4.120     0.0    0.0  0.0       0.0    1468.0  yes
# 4          4.963     0.0    0.0  0.0       0.0      36.0   no

# %%
data_clean['y'] = data_clean['y'].map({'yes':1, 'no':2})
data_clean.head(25)
# Out:
#     interest_rate  credit  march  may  previous  duration  y
# 0           1.313     0.0    1.0  0.0       0.0     487.0  2
# 1           4.961     0.0    0.0  0.0       0.0     132.0  2
# 2           4.856     0.0    1.0  0.0       0.0      92.0  2
# 3           4.120     0.0    0.0  0.0       0.0    1468.0  1
# 4           4.963     0.0    0.0  0.0       0.0      36.0  2
# 5           0.697     0.0    1.0  4.0       0.0     131.0  2
# 6           0.639     1.0    0.0  0.0       0.0     215.0  1
# 7           4.120     0.0    0.0  0.0       0.0     499.0  2
# 8           1.281     0.0    1.0  1.0       0.0     809.0  1
# 9           4.966     0.0    0.0  0.0       0.0     389.0  2
# 10          4.965     0.0    0.0  0.0       0.0     168.0  2
# 11          4.968     0.0    0.0  0.0       0.0     766.0  1
# 12          0.714     0.0    0.0  1.0       0.0     192.0  1
# 13          1.410     0.0    0.0  1.0       0.0      48.0  2
# ...

# %%
data_mapped = data_clean.copy()
data_mapped.head()
# Out:
#    interest_rate  credit  march  may  previous  duration  y
# 0          1.313     0.0    1.0  0.0       0.0     487.0  2
# 1          4.961     0.0    0.0  0.0       0.0     132.0  2
# 2          4.856     0.0    1.0  0.0       0.0      92.0  2
# 3          4.120     0.0    0.0  0.0       0.0    1468.0  1
# 4          4.963     0.0    0.0  0.0       0.0      36.0  2

# %%
data_mapped.describe()
# Out:
#        interest_rate      credit       march         may    previous  \
# count     222.000000  222.000000  222.000000  222.000000  222.000000
# mean        2.922095    0.031532    0.274775    0.346847    0.099099
# std         1.891766    0.175144    0.447410    0.755950    0.299470
# min         0.639000    0.000000    0.000000    0.000000    0.000000
# 25%         1.049250    0.000000    0.000000    0.000000    0.000000
# 50%         1.714000    0.000000    0.000000    0.000000    0.000000
# 75%         4.960000    0.000000    1.000000    0.000000    0.000000
# max         4.968000    1.000000    1.000000    4.000000    1.000000
#
#           duration          y
# count   222.000000  222.00000
# mean    398.860360    1.50000
# std     410.565798    0.50113
# min       6.000000    1.00000
# 25%     144.750000    1.00000
# 50%     255.500000    1.50000
# 75%     525.250000    2.00000
# max    3643.000000    2.00000
